# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = 'SQ4_part_b.csv'
df_SQ4B = pd.read_csv(file_path, sep=';')

df_compared = df_SQ4B.melt(id_vars='Age', value_vars=['2018', '2019', '2020', '2021'], var_name='Year', value_name='Fatalities')

sns.set_palette("deep")
plt.figure(figsize=(12, 6))
sns.barplot(data=df_melted, x='Year', y='Fatalities', hue='Age')

plt.title('Fatal accidents per billion kilometers')
plt.xlabel('Year')
plt.ylabel('Fatal accidents')
plt.grid(True)
plt.legend(title='Age groups', bbox_to_anchor=(1, 1), loc='upper left')

# Laat de plot zien
plt.show()
